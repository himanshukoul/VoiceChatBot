# %% [markdown]
# # Service

# %%
# !pip install pyngrok
from pyngrok import ngrok
from google.colab import userdata
key = userdata.get('ngrok')
ngrok.set_auth_token(key)
# Out:
# Collecting pyngrok
#   Downloading pyngrok-7.2.12-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.11/dist-packages (from pyngrok) (6.0.2)
# Downloading pyngrok-7.2.12-py3-none-any.whl (26 kB)
# Installing collected packages: pyngrok
# Successfully installed pyngrok-7.2.12

# %%
# !pip install flask flask-cors torchaudio git+https://github.com/openai/whisper.git -q

import whisper, torch
import io
from flask import Flask, request, jsonify
from flask_cors import CORS
import torchaudio
import base64
from pyngrok import ngrok
import threading

device = "cuda" if torch.cuda.is_available() else "cpu"
model = whisper.load_model("small.en").to(device)

app = Flask(__name__)
CORS(app)

@app.route("/stt", methods=["POST"])
def transcribe_audio():
    try:
        file = request.files["file"]
        filepath = "/tmp/temp.wav"
        file.save(filepath)
        result = model.transcribe(filepath)
        return jsonify({"text": result.get("text", "")})
    except Exception as e:
        return jsonify({"error": str(e)}), 500

def run_flask():
    app.run(port=5001)

threading.Thread(target=run_flask).start()

public_url = ngrok.connect(5001)
print("Public URL:", public_url)
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 18.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 14.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 13.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 21.1 MB/s eta 0:00:00
#   Building wheel for openai-whisper (pyproject.toml) ... done
# 100%|███████████████████████████████████████| 461M/461M [00:58<00:00, 8.25MiB/s]
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5001
# INFO:werkzeug:Press CTRL+C to quit
# Public URL: NgrokTunnel: "https://b0c527125540.ngrok-free.app" -> "http://localhost:5001"
